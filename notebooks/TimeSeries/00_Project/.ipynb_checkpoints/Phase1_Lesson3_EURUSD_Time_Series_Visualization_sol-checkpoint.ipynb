# %% [markdown]
# # Phase 1 — Lesson 3: Time Series Visualization
# ## EUR/USD H4 Practice Notebook
#
# Dataset path: `Data/EURUSD_H4.csv`
#
# ### Lesson goals
# - Load and inspect EUR/USD H4 data.
# - Plot the full time series.
# - Plot one year, one month, and one trading day.
# - Compare Open vs Close.
# - Compare High vs Low.
# - Plot Volume.
# - Improve chart readability.
# - Complete exercises and a final practice task.
#
# > This notebook focuses on visualization only. It does not introduce smoothing, rolling statistics, stationarity, decomposition, or forecasting.

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Load the EUR/USD H4 dataset
#
# The file path is:
#
# `Data/EURUSD_H4.csv`

# %%
eurusd = pd.read_csv(
    "Data/EURUSD_H4.csv",
    parse_dates=["DateTime"],
    index_col="DateTime"
)

eurusd = eurusd.sort_index()

eurusd.head()
# Out:
#                               Open     High      Low    Close     Volume
# DateTime
# 2008-12-31 20:00:00+00:00  1.39658  1.39945  1.39574  1.39746   57197.00
# 2009-01-01 00:00:00+00:00  1.39734  1.39754  1.39672  1.39702   38071.80
# 2009-01-01 04:00:00+00:00  1.39716  1.39740  1.39663  1.39700   67849.25
# 2009-01-01 08:00:00+00:00  1.39708  1.40370  1.39700  1.40367  128442.75
# 2009-01-01 12:00:00+00:00  1.40346  1.40707  1.40346  1.40682  128985.65

# %% [markdown]
# ## 3. Inspect the dataset

# %%
eurusd.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 30561 entries, 2008-12-31 20:00:00+00:00 to 2026-09-01 20:00:00+00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    30561 non-null  float64
#  1   High    30561 non-null  float64
#  2   Low     30561 non-null  float64
#  3   Close   30561 non-null  float64
#  4   Volume  30561 non-null  float64
# dtypes: float64(5)
# memory usage: 1.4 MB

# %%
print(f"First timestamp: {eurusd.index.min()}")
print(f"Last timestamp : {eurusd.index.max()}")
print(f"Rows           : {len(eurusd):,}")
print(f"Columns        : {list(eurusd.columns)}")
# Out:
# First timestamp: 2008-12-31 20:00:00+00:00
# Last timestamp : 2026-09-01 20:00:00+00:00
# Rows           : 30,561
# Columns        : ['Open', 'High', 'Low', 'Close', 'Volume']

# %% [markdown]
# ## 4. Plot the full EUR/USD Close series
#
# A line chart is usually the first visualization to try for time-series data because time order matters.

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    eurusd.index,
    eurusd["Close"]
)

plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 Closing Price — Full Dataset")
plt.grid()

plt.show()

# %% [markdown]
# ### What should you look for?
#
# With the full dataset, focus on the big picture:
#
# - broad upward or downward movements,
# - major turning points,
# - long periods of relatively high or low prices,
# - periods with stronger or weaker fluctuations.
#
# A long time range gives context, but it hides short-term detail.

# %% [markdown]
# ## 5. Plot one year — 2025

# %%
eurusd_2025 = eurusd.loc["2025"]

plt.figure(figsize=(15, 6))

plt.plot(
    eurusd_2025.index,
    eurusd_2025["Close"]
)

plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 Closing Price — 2025")
plt.xticks(rotation=45)
plt.grid()

plt.show()

# %% [markdown]
# `plt.xticks(rotation=45)` rotates the x-axis date labels by 45 degrees, making them easier to read when dates are crowded.

# %% [markdown]
# ## 6. Plot one month — November 2025

# %%
eurusd_nov_2025 = eurusd.loc["2025-11"]

plt.figure(figsize=(15, 6))

plt.plot(
    eurusd_nov_2025.index,
    eurusd_nov_2025["Close"],
    marker="o"
)

plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 Closing Price — November 2025")
plt.xticks(rotation=45)
plt.grid()

plt.show()

# %% [markdown]
# Markers are useful on shorter time windows because they make individual H4 observations easier to see. On very long ranges they can make a plot too crowded.

# %% [markdown]
# ## 7. Plot one trading day

# %%
eurusd_day = eurusd.loc["2025-11-05"]

plt.figure(figsize=(10, 5))

plt.plot(
    eurusd_day.index,
    eurusd_day["Close"],
    marker="o"
)

plt.xlabel("Time")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 Closing Price — 2025-11-05")
plt.xticks(rotation=45)
plt.grid()

plt.show()

# %%
print(f"Candles in this day: {len(eurusd_day)}")
print(f"Candle hours: {sorted(eurusd_day.index.hour.unique())}")
# Out:
# Candles in this day: 6
# Candle hours: [0, 4, 8, 12, 16, 20]

# %% [markdown]
# For H4 data, a complete trading day may contain candles at:
#
# `00:00, 04:00, 08:00, 12:00, 16:00, 20:00`

# %% [markdown]
# ## 8. Compare Open and Close

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    eurusd_nov_2025.index,
    eurusd_nov_2025["Open"],
    label="Open"
)

plt.plot(
    eurusd_nov_2025.index,
    eurusd_nov_2025["Close"],
    label="Close"
)

plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 Open vs Close — November 2025")
plt.xticks(rotation=45)
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# When more than one line is plotted, `plt.legend()` identifies each series.

# %% [markdown]
# ## 9. Compare High and Low

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    eurusd_nov_2025.index,
    eurusd_nov_2025["High"],
    label="High"
)

plt.plot(
    eurusd_nov_2025.index,
    eurusd_nov_2025["Low"],
    label="Low"
)

plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 High vs Low — November 2025")
plt.xticks(rotation=45)
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ## 10. Plot all OHLC prices together

# %%
plt.figure(figsize=(15, 6))

plt.plot(eurusd_nov_2025.index, eurusd_nov_2025["Open"], label="Open")
plt.plot(eurusd_nov_2025.index, eurusd_nov_2025["High"], label="High")
plt.plot(eurusd_nov_2025.index, eurusd_nov_2025["Low"], label="Low")
plt.plot(eurusd_nov_2025.index, eurusd_nov_2025["Close"], label="Close")

plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 OHLC Prices — November 2025")
plt.xticks(rotation=45)
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ### Visualization lesson
#
# More lines do not always make a better chart. If the chart becomes difficult to read, reduce the number of variables, shorten the time range, or both.

# %% [markdown]
# ## 11. Plot Volume separately

# %%
plt.figure(figsize=(15, 5))

plt.plot(
    eurusd_nov_2025.index,
    eurusd_nov_2025["Volume"]
)

plt.xlabel("Date")
plt.ylabel("Volume")
plt.title("EUR/USD H4 Volume — November 2025")
plt.xticks(rotation=45)
plt.grid()

plt.show()

# %% [markdown]
# ## 12. Compare different time windows
#
# The same time series can look very different depending on the time window.
#
# - Full dataset → big-picture view
# - One year → medium-term view
# - One month → detailed view
# - One day → individual H4 observations
#
# Always choose the time window based on the question you are trying to answer.

# %% [markdown]
# ## 13. Reusable plotting pattern

# %%
data = eurusd.loc["2025-11"]

plt.figure(figsize=(15, 6))

plt.plot(
    data.index,
    data["Close"]
)

plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD Closing Price")
plt.xticks(rotation=45)
plt.grid()

plt.show()

# %% [markdown]
# # Practice Exercises
#
# Try these yourself before looking back at the examples above.

# %% [markdown]
# ## Exercise 1 — Plot another year
#
# Plot the EUR/USD `Close` price for **2024**.
#
# Requirements:
# - figure size `(15, 6)`
# - x-axis label: `Date`
# - y-axis label: `EUR/USD`
# - title: `EUR/USD H4 Closing Price — 2024`
# - rotate x-axis labels by 45 degrees
# - add gridlines

# %%
eurusd2024= eurusd.loc['2024']
eurusd2024
# Out:
#                               Open     High      Low    Close    Volume
# DateTime
# 2024-01-01 20:00:00+00:00  1.10427  1.10447  1.10356  1.10365   3923.96
# 2024-01-02 00:00:00+00:00  1.10366  1.10432  1.10176  1.10245  24509.62
# 2024-01-02 04:00:00+00:00  1.10245  1.10380  1.10151  1.10153  30174.74
# 2024-01-02 08:00:00+00:00  1.10156  1.10387  1.09665  1.09690  70041.65
# 2024-01-02 12:00:00+00:00  1.09691  1.09717  1.09410  1.09435  86422.11
# ...                            ...      ...      ...      ...       ...
# 2024-12-31 04:00:00+00:00  1.04084  1.04129  1.03996  1.04118  12254.00
# 2024-12-31 08:00:00+00:00  1.04120  1.04243  1.04051  1.04103  33694.25
# 2024-12-31 12:00:00+00:00  1.04103  1.04143  1.03525  1.03547  76535.14
# 2024-12-31 16:00:00+00:00  1.03548  1.03646  1.03440  1.03547  30184.98
# 2024-12-31 20:00:00+00:00  1.03547  1.03630  1.03526  1.03526   4499.56
#
# [1616 rows x 5 columns]

# %%
# Write your Exercise 1 code here
plt.figure(figsize=(15, 6))
plt.plot(eurusd2024.index, eurusd2024["Close"])
plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 Closing Price — 2024")
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# ## Exercise 2 — Plot another month
#
# Plot the EUR/USD `Close` price for **March 2025** and add markers.

# %%
# Write your Exercise 2 code here
eurusd202503 = eurusd.loc['2025-03']
plt.figure(figsize=(15, 6))
plt.plot(eurusd202503.index, eurusd202503["Close"])
plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 Closing Price — March 2025")
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# ## Exercise 3 — Open vs Close
#
# For **March 2025**:
#
# 1. Plot `Open`.
# 2. Plot `Close`.
# 3. Put both on the same graph.
# 4. Add a legend.
# 5. Add a title and gridlines.

# %%
# Write your Exercise 3 code here
plt.figure(figsize=(15, 6))
plt.plot(eurusd202503.index, eurusd202503["Open"],label="Open",color="green")
plt.plot(eurusd202503.index, eurusd202503["Close"],label="Close",color="red")
plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 Open / Closing Price — March 2025")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Exercise 4 — One trading day
#
# Choose any trading day from March 2025.
#
# Then:
# 1. display the rows for that day,
# 2. count the H4 candles,
# 3. print the unique candle hours,
# 4. plot the Close price.

# %%
# Write your Exercise 4 code here
eurusd_20250311=eurusd.loc["2025-03-11"]
print(eurusd_20250311)
print(f"Nubmer of candles is : {len(eurusd_20250311)}")
print(f"Unique Candle Hours : {eurusd_20250311.index.hour.unique()}")
print(f"Candle hours: {sorted(eurusd_day.index.hour.unique())}")
print(f"Candle hours: {sorted(eurusd_day.index.hour.unique())}")
# Out:
#                               Open     High      Low    Close    Volume
# DateTime
# 2025-03-11 00:00:00+00:00  1.08390  1.08604  1.08389  1.08542  26842.99
# 2025-03-11 04:00:00+00:00  1.08540  1.09014  1.08354  1.08906  31742.49
# 2025-03-11 08:00:00+00:00  1.08906  1.09207  1.08810  1.09044  41265.45
# 2025-03-11 12:00:00+00:00  1.09044  1.09306  1.08949  1.09270  56401.69
# 2025-03-11 16:00:00+00:00  1.09269  1.09471  1.09177  1.09196  34222.95
# 2025-03-11 20:00:00+00:00  1.09199  1.09209  1.09068  1.09136   9255.46
# Nubmer of candles is : 6
# Unique Candle Hours : Index([0, 4, 8, 12, 16, 20], dtype='int32', name='DateTime')
# Candle hours: [0, 4, 8, 12, 16, 20]
# Candle hours: [0, 4, 8, 12, 16, 20]

# %%
plt.figure(figsize=(15, 6))
plt.plot(eurusd_20250311.index, eurusd_20250311["Close"],label="Close",color="red")
plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 Closing Price — 11 March 2025")
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# # Final Practice Task
#
# Create a small EUR/USD visualization report for **one month of your choice in 2025**.
#
# Create:
#
# 1. Closing-price plot.
# 2. Open vs Close plot.
# 3. High vs Low plot.
# 4. Volume plot.
#
# For every graph:
# - choose an appropriate figure size,
# - write a clear title,
# - label the axes,
# - rotate date labels when necessary,
# - use gridlines,
# - use a legend when more than one line is shown.
#
# Afterward, write **3 visual observations**.
#
# Do not calculate rolling averages, decomposition, stationarity, or forecasting models yet.

# %%
# Final Practice Task

# Choose one month in 2025
# Example format:
# practice_month = eurusd.loc["2025-03"]
practice_month = eurusd.loc["2025-01"]
plt.figure(figsize=(15, 6))
# Plot 1 — Close
plt.plot(practice_month.index, practice_month["Close"],label="Close")

# Plot 2 — Open vs Close
plt.plot(practice_month.index, practice_month["Open"],label="Open")

# Plot 3 — High vs Low
plt.plot(practice_month.index, practice_month["High"],label="High")
plt.plot(practice_month.index, practice_month["Low"],label="Low")

# Plot 4 — Volume
# plt.plot(practice_month.index, practice_month["Volume"],label="Volume")

plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 Closing Price — 11 March 2025")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Plot 1 — Close

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    practice_month.index,
    practice_month["Close"],
    label="Close"
)

plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 Closing Price — January 2025")
plt.xticks(rotation=45)
plt.grid()

plt.show()

# %% [markdown]
# ### Plot 2 — Open vs Close

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    practice_month.index,
    practice_month["Open"],
    label="Open"
)

plt.plot(
    practice_month.index,
    practice_month["Close"],
    label="Close"
)

plt.xlabel("Date")
plt.ylabel("EUR/USD")
plt.title("EUR/USD H4 Open vs Close — January 2025")
plt.xticks(rotation=45)
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ## Write your observations
#
# 1.
# 2.
# 3.

# %% [markdown]
# # Lesson 3 Cheat Sheet
#
# ### Basic line plot
#
# ```python
# plt.figure(figsize=(15, 6))
# plt.plot(df.index, df["Close"])
# plt.xlabel("Date")
# plt.ylabel("Value")
# plt.title("Chart Title")
# plt.xticks(rotation=45)
# plt.grid()
# plt.show()
# ```
#
# ### Filter one year
#
# ```python
# eurusd.loc["2025"]
# ```
#
# ### Filter one month
#
# ```python
# eurusd.loc["2025-11"]
# ```
#
# ### Filter one day
#
# ```python
# eurusd.loc["2025-11-05"]
# ```
#
# ### Multiple lines
#
# ```python
# plt.plot(df.index, df["Open"], label="Open")
# plt.plot(df.index, df["Close"], label="Close")
# plt.legend()
# ```
#
# ### Main lesson
#
# A time-series chart changes depending on the time window.
#
# - Long window → overall picture
# - Short window → more detail
